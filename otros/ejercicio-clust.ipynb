# %% [markdown]
# # **Elements of Machine Learning 2024** <font size=4 color='gray'>Alan Reyes-Figueroa</font>
# #### <font color='gray'>Ejercicio clustering</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, DBSCAN, MeanShift, OPTICS, Birch

from sklearn.metrics import rand_score, adjusted_rand_score, homogeneity_completeness_v_measure
from sklearn.metrics import mutual_info_score, normalized_mutual_info_score, adjusted_mutual_info_score
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score
from sklearn.metrics import fowlkes_mallows_score, calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score, silhouette_samples, silhouette_score

from sklearn.cluster import k_means, KMeans, Birch, DBSCAN, OPTICS, mean_shift, KMeans, MeanShift
from sklearn.cluster import AgglomerativeClustering, SpectralClustering

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Datos

# %% [markdown]
# Leer los datos en "Datos_clustering.csv" en un dataframe, y guardar la matriz de datos en un numpy array $X$.
# Esta matriz debería ser de tamaño $500 \times 2$.

# %% [markdown]
# # Determinar el número de clústers

# %% [markdown]
# Aplicar el algoritmo de Mean-Shift para determinar el número de clústers adecuado para el conjunto de datos "Datos_clustering.csv".
#
# * Verificar cuántos labels diferentes hay según el algoritmo Mean-Shift.
#
# * Hacer un plot de los datos (coloreados según los labels), para visualizar el resultado del Mean-Shift.
# ¿Es adecuada la clusterización? Discutir el resultado.

# %% [markdown]
# # Determinar el número de clústers usando la métrica de Davies-Bouldin

# %% [markdown]
# Aplicar varias veces algún algoritmos de clustering (Kmeans o cualquier otro) a los datos. En cada ocasión, cambiar el número de clúster utilizados. Por ejemplo, iterar desde $k = 2$ hasta $k = 10$.
#
# En cada iteración, calcular la métrica de Davies-Bouldin obtenida, y guardarla en un vector de numpy.
#
# * Graficar en un plot los resultados de la métrica de Davies-Bouldin en función de $k$.
#
# * ¿Cuál es el número de clústers sugerido por esta métrica?

# %% [markdown]
# # Determinar el número de clústers usando la métrica de Siluetas

# %% [markdown]
# Aplicar varias veces algún algoritmos de clustering (Kmeans o cualquier otro) a los datos. En cada ocasión, cambiar el número de clúster utilizados. Por ejemplo, iterar desde $k = 2$ hasta $k = 10$.
#
# En cada iteración, calcular la métrica de Siluetas (silueta promedio) obtenida, y guardarla en un vector de numpy.
# No es necesario graficar todas las siluetas, sólo calcular el score promedio de este método. Se puede hacer a través de la función
#
# $\texttt{silhouette_score(X, labels)}$
#
# * Graficar en un plot los resultados del score de Siluetas en función de $k$.
#
# * ¿Cuál es el número de clústers sugerido por esta métrica?
